# %%
import os
import sys
import json

import pandas as pd
import numpy as np
from sklearn.svm import SVC
from sklearn import metrics
from sklearn.model_selection import cross_val_predict

# %%
module_path = os.path.abspath(os.path.join('../'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from src.preprocessing.normalization.functional_normalization import functional_normalize_by
from src.evaluation.evaluate_scores import evaluate_scores
from src.learning.parameter_tuning import ParamSearch
from config import ROOT_DIR, AUDIO_FUNCTIONALS_EGEMAPS_COLS
from src.visualization.plot_means import plot_means_and_stds
from src.utils.get_splits import get_splits
from src.visualization.histogram import plot_hist
from src.visualization.confusion_matrix import ConfusionMatrixCreator, plot_conf_mat

# %%
AUDIO_VISUALIZATION_COLS = [
    'F0semitoneFrom27.5Hz_sma3nz_amean',
    'loudness_sma3_amean',
]

# %%
# paths
input_data = os.path.join(ROOT_DIR, "files/data/opensmile_functionals.csv")
output_data = os.path.join(ROOT_DIR, "files/out")

# %%
df = pd.read_csv(input_data, delimiter=";")

# %%
df
# Out:
#       Unnamed: 0            sttmnt_ID  Participant Statement  Accuracy  \
# 0              1   S2_w01_t1_s01.wav'            1         1         1
# 1              2   S2_w01_t1_s10.wav'            1        10         1
# 2              3   S2_w01_t1_s11.wav'            1        11         1
# 3              4   S2_w01_t1_s12.wav'            1        12         1
# 4              5   S2_w01_t1_s13.wav'            1        13         1
# ...          ...                  ...          ...       ...       ...
# 3543        3544  'S2_w09_t1_s67.wav'            9        67         0
# 3544        3545  'S2_w09_t1_s68.wav'            9        68         0
# 3545        3546  'S2_w09_t1_s07.wav'            9         7         1
# 3546        3547  'S2_w09_t1_s08.wav'            9         8         1
# 3547        3548  'S2_w09_t1_s09.wav'            9         9         1
#
#       Confidence_level  Confidence_type  Free_cued_recall  \
# 0                100.0              1.0                 1
# 1                  NaN              NaN                 1
# 2                  NaN              NaN                 1
# 3                  NaN              NaN                 1
# 4                100.0              1.0                 1
# ...                ...              ...               ...
# 3543              40.0              1.0                 2
# 3544              40.0              1.0                 2
# 3545              80.0              1.0                 1
# 3546             100.0              1.0                 1
# 3547             100.0              2.0                 2
#
#       F0semitoneFrom27.5Hz_sma3nz_amean  \
# 0                              34.36551
# 1                              25.96453
# 2                              28.89816
# 3                              27.56384
# 4                              28.47333
# ...                                 ...
# 3543                           32.79814
# 3544                           26.07878
# 3545                           29.64281
# 3546                           27.60379
# 3547                           34.56275
#
#       F0semitoneFrom27.5Hz_sma3nz_stddevNorm  ...  slopeUV0.500_sma3nz_amean  \
# 0                                   0.136942  ...                  -0.037406
# 1                                   0.271193  ...                  -0.054731
# 2                                   0.212653  ...                  -0.049107
# 3                                   0.221763  ...                  -0.056503
# 4                                   0.204346  ...                  -0.048038
# ...                                      ...  ...                        ...
# 3543                                0.099313  ...                  -0.062526
# 3544                                0.311368  ...                  -0.068615
# 3545                                0.148856  ...                  -0.049520
# 3546                                0.268069  ...                  -0.056958
# 3547                                0.136758  ...                  -0.066067
#
#       slopeUV500.1500_sma3nz_amean  spectralFluxUV_sma3nz_amean  \
# 0                        -0.007398                     0.227092
# 1                        -0.010005                     0.174763
# 2                        -0.009912                     0.145613
# 3                        -0.007487                     0.166699
# 4                        -0.012770                     0.127892
# ...                            ...                          ...
# 3543                     -0.012370                     0.063130
# 3544                     -0.005863                     0.131412
# 3545                     -0.009493                     0.109803
# 3546                     -0.008350                     0.166478
# 3547                     -0.003207                     0.169858
#
#       loudnessPeaksPerSec  VoicedSegmentsPerSec  MeanVoicedSegmentLengthSec  \
# 0                2.985075              2.431611                    0.273750
# 1                1.526718              2.695764                    0.124286
# 2                3.191489              2.964960                    0.127273
# 3                2.303263              3.100775                    0.194375
# 4                3.787879              3.333333                    0.119231
# ...                   ...                   ...                         ...
# 3543             1.960784              1.600000                    0.285000
# 3544             2.256944              0.525394                    0.080000
# 3545             2.551985              2.089269                    0.176364
# 3546             1.785714              2.004008                    0.105000
# 3547             3.448276              2.040816                    0.300000
#
#       StddevVoicedSegmentLengthSec  MeanUnvoicedSegmentLength  \
# 0                         0.273173                   0.115000
# 1                         0.097764                   0.261667
# 2                         0.110131                   0.188182
# 3                         0.149331                   0.114667
# 4                         0.131058                   0.188182
# ...                            ...                        ...
# 3543                      0.170660                   0.320000
# 3544                      0.056569                   1.350000
# 3545                      0.189941                   0.294286
# 3546                      0.096670                   0.372000
# 3547                      0.000000                   0.080000
#
#       StddevUnvoicedSegmentLength  equivalentSoundLevel_dBp
# 0                        0.064226                 -36.21673
# 1                        0.420809                 -40.86316
# 2                        0.153019                 -40.07899
# 3                        0.099791                 -37.72633
# 4                        0.110767                 -40.21887
# ...                           ...                       ...
# 3543                     0.201618                 -42.12679
# 3544                     1.910340                 -46.44904
# 3545                     0.462865                 -41.92608
# 3546                     0.463353                 -42.42829
# 3547                     0.050000                 -34.80136
#
# [3548 rows x 96 columns]

# %%
y = df["Accuracy"].values
x = df[AUDIO_FUNCTIONALS_EGEMAPS_COLS].values
participant = df["Participant"].values

# %%
plot_hist(y, "labels")

# %% [markdown]
# ## Normalization

# %%
plot_means_and_stds(x, y, AUDIO_VISUALIZATION_COLS, "pre")

# %%
x = functional_normalize_by(x, participant, method="min_max")

# %%
plot_means_and_stds(x, y, AUDIO_VISUALIZATION_COLS, "post")

# %% [markdown]
# # Parameter search, training and evaluation

# %%
def search_train_evaluate(x, y, parameter_search_scoring):
    print("Evaluation with {} scoring in parameter search".format(parameter_search_scoring))
    
    params_path = os.path.join(output_data, "best_params_" + parameter_search_scoring + ".json")
    
    print()

    ps = ParamSearch()
    clf = ps.param_search(x, y, parameter_search_scoring)
    clf.best_params_

    with open(params_path, "w") as outfile:
        # writing to json file
        json.dump(clf.best_params_, outfile)

    with open(params_path, 'r') as openfile:
        # Reading from json file
        best_params = json.load(openfile)
    
    print(best_params)
    svc = SVC(**best_params)
    print()
    evaluate_scores(x=x,
                    y=y,
                    clf=svc,
                    scoring_method="roc_auc")
    print()
    svc = SVC(**best_params)
    evaluate_scores(x=x,
                    y=y,
                    clf=svc,
                    scoring_method="accuracy")
    print()
    svc = SVC(**best_params)
    evaluate_scores(x=x,
                    y=y,
                    clf=svc,
                    scoring_method="f1_macro")

    splits = get_splits(x, y)
    y_pred = cross_val_predict(svc, x, y, cv=splits)

    plot_hist(y_pred, "predictions")

    report = metrics.classification_report(y_true=y, y_pred=y_pred)
    print(report)
    
    splits = get_splits(x, y)
    conf_mat_creator = ConfusionMatrixCreator(clf=svc)
    conf_mat = conf_mat_creator.calculate_avg_conf_matrix(x, y, splits)
    print(conf_mat)
    plot_conf_mat(conf_mat)

# %% [markdown]
# ### Parameter search with AUC scoring

# %%
search_train_evaluate(x, y, "roc_auc")
# Out:
# Evaluation with roc_auc scoring in parameter search
#
# {'C': 1, 'class_weight': 'balanced', 'gamma': 0.1, 'kernel': 'rbf'}
# {'C': 1, 'class_weight': 'balanced', 'gamma': 0.1, 'kernel': 'rbf'}
#
# printing roc_auc measures
# avg (train): 0.8078479246470351
# std (train): 0.004291630641423225
# avg (validation): 0.6294530945426859
# std (validation): 0.022508037216873583
#
# printing accuracy measures
# avg (train): 0.7022966627372043
# std (train): 0.00721348586797871
# avg (validation): 0.6135807227000933
# std (validation): 0.01593171051163849
#
# printing f1_macro measures
# avg (train): 0.6647386200350384
# std (train): 0.0052663803401243195
# avg (validation): 0.5634554587730671
# std (validation): 0.017325753120825755
#               precision    recall  f1-score   support
#
#            0       0.32      0.58      0.42       839
#            1       0.83      0.62      0.71      2709
#
#     accuracy                           0.61      3548
#    macro avg       0.58      0.60      0.56      3548
# weighted avg       0.71      0.61      0.64      3548
#
# [[0.58158683 0.41841317]
#  [0.37652973 0.62347027]]

# %% [markdown]
# ### Parameter search with Accuracy scoring

# %%
search_train_evaluate(x, y, "accuracy")
# Out:
# Evaluation with accuracy scoring in parameter search
#
# {'C': 5, 'class_weight': 'balanced', 'gamma': 1, 'kernel': 'rbf'}
# {'C': 5, 'class_weight': 'balanced', 'gamma': 1, 'kernel': 'rbf'}
#
# printing roc_auc measures
# avg (train): 1.0
# std (train): 0.0
# avg (validation): 0.604892720680281
# std (validation): 0.014216448575109893
#
# printing accuracy measures
# avg (train): 1.0
# std (train): 0.0
# avg (validation): 0.7587369633882278
# std (validation): 0.0016869904662969038
#
# printing f1_macro measures
# avg (train): 1.0
# std (train): 0.0
# avg (validation): 0.4601678232632388
# std (validation): 0.011850310657832392
#               precision    recall  f1-score   support
#
#            0       0.38      0.03      0.06       839
#            1       0.77      0.98      0.86      2709
#
#     accuracy                           0.76      3548
#    macro avg       0.57      0.51      0.46      3548
# weighted avg       0.68      0.76      0.67      3548
#
# [[0.03215711 0.96784289]
#  [0.0162423  0.9837577 ]]

# %% [markdown]
# ### Parameter search with F1_macro scoring

# %%
search_train_evaluate(x, y, "f1_macro")
# Out:
# Evaluation with f1_macro scoring in parameter search
# Process LokyProcess-67:
# Traceback (most recent call last):
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 620, in __call__
#     return self.func(*args, **kwargs)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/parallel.py", line 288, in __call__
#     return [func(*args, **kwargs)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/parallel.py", line 288, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/sklearn/utils/parallel.py", line 123, in __call__
#     return self.function(*args, **kwargs)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/sklearn/svm/_base.py", line 252, in fit
#     fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/sklearn/svm/_base.py", line 331, in _dense_fit
#     ) = libsvm.fit(
# KeyboardInterrupt
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py", line 428, in _process_worker
#     r = call_item()
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py", line 275, in __call__
#     return self.fn(*self.args, **self.kwargs)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 625, in __call__
#     raise WorkerInterrupt() from e
# joblib.my_exceptions.WorkerInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py", line 431, in _process_worker
#     result_queue.put(_ResultItem(call_item.work_id, exception=exc))
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/externals/loky/backend/queues.py", line 191, in put
#     with self._wlock:
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/externals/loky/backend/synchronize.py", line 112, in __enter__
#     return self._semlock.acquire()
# KeyboardInterrupt
# Process LokyProcess-61:
# Traceback (most recent call last):
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 620, in __call__
#     return self.func(*args, **kwargs)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/parallel.py", line 288, in __call__
#     return [func(*args, **kwargs)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/parallel.py", line 288, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/sklearn/utils/parallel.py", line 123, in __call__
#     return self.function(*args, **kwargs)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/sklearn/svm/_base.py", line 252, in fit
#     fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/sklearn/svm/_base.py", line 331, in _dense_fit
#     ) = libsvm.fit(
# KeyboardInterrupt
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py", line 428, in _process_worker
#     r = call_item()
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py", line 275, in __call__
#     return self.fn(*self.args, **self.kwargs)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 625, in __call__
#     raise WorkerInterrupt() from e
# joblib.my_exceptions.WorkerInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py", line 431, in _process_worker
#     result_queue.put(_ResultItem(call_item.work_id, exception=exc))
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/externals/loky/backend/queues.py", line 191, in put
#     with self._wlock:
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/externals/loky/backend/synchronize.py", line 112, in __enter__
#     return self._semlock.acquire()
# KeyboardInterrupt
# Process LokyProcess-55:
# Traceback (most recent call last):
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 620, in __call__
#     return self.func(*args, **kwargs)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/parallel.py", line 288, in __call__
#     return [func(*args, **kwargs)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/parallel.py", line 288, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/sklearn/utils/parallel.py", line 123, in __call__
#     return self.function(*args, **kwargs)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/sklearn/svm/_base.py", line 252, in fit
#     fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/sklearn/svm/_base.py", line 331, in _dense_fit
#     ) = libsvm.fit(
# KeyboardInterrupt
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py", line 428, in _process_worker
#     r = call_item()
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py", line 275, in __call__
#     return self.fn(*self.args, **self.kwargs)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 625, in __call__
#     raise WorkerInterrupt() from e
# joblib.my_exceptions.WorkerInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py", line 431, in _process_worker
#     result_queue.put(_ResultItem(call_item.work_id, exception=exc))
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/externals/loky/backend/queues.py", line 191, in put
#     with self._wlock:
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/externals/loky/backend/synchronize.py", line 112, in __enter__
#     return self._semlock.acquire()
# KeyboardInterrupt
# Process LokyProcess-58:
# Traceback (most recent call last):
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 620, in __call__
#     return self.func(*args, **kwargs)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/parallel.py", line 288, in __call__
#     return [func(*args, **kwargs)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/parallel.py", line 288, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/sklearn/utils/parallel.py", line 123, in __call__
#     return self.function(*args, **kwargs)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/sklearn/svm/_base.py", line 252, in fit
#     fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/sklearn/svm/_base.py", line 331, in _dense_fit
#     ) = libsvm.fit(
# KeyboardInterrupt
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py", line 428, in _process_worker
#     r = call_item()
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py", line 275, in __call__
#     return self.fn(*self.args, **self.kwargs)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 625, in __call__
#     raise WorkerInterrupt() from e
# joblib.my_exceptions.WorkerInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py", line 431, in _process_worker
#     result_queue.put(_ResultItem(call_item.work_id, exception=exc))
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/externals/loky/backend/queues.py", line 191, in put
#     with self._wlock:
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/externals/loky/backend/synchronize.py", line 112, in __enter__
#     return self._semlock.acquire()
# KeyboardInterrupt
# Process LokyProcess-59:
# Traceback (most recent call last):
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 620, in __call__
#     return self.func(*args, **kwargs)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/parallel.py", line 288, in __call__
#     return [func(*args, **kwargs)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/parallel.py", line 288, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/sklearn/utils/parallel.py", line 123, in __call__
#     return self.function(*args, **kwargs)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/sklearn/svm/_base.py", line 252, in fit
#     fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/sklearn/svm/_base.py", line 331, in _dense_fit
#     ) = libsvm.fit(
# KeyboardInterrupt
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py", line 428, in _process_worker
#     r = call_item()
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py", line 275, in __call__
#     return self.fn(*self.args, **self.kwargs)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 625, in __call__
#     raise WorkerInterrupt() from e
# joblib.my_exceptions.WorkerInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py", line 431, in _process_worker
#     result_queue.put(_ResultItem(call_item.work_id, exception=exc))
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/externals/loky/backend/queues.py", line 191, in put
#     with self._wlock:
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/externals/loky/backend/synchronize.py", line 112, in __enter__
#     return self._semlock.acquire()
# KeyboardInterrupt
# Process LokyProcess-54:
# Traceback (most recent call last):
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 620, in __call__
#     return self.func(*args, **kwargs)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/parallel.py", line 288, in __call__
#     return [func(*args, **kwargs)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/parallel.py", line 288, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/sklearn/utils/parallel.py", line 123, in __call__
#     return self.function(*args, **kwargs)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/sklearn/svm/_base.py", line 252, in fit
#     fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/sklearn/svm/_base.py", line 331, in _dense_fit
#     ) = libsvm.fit(
# KeyboardInterrupt
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py", line 428, in _process_worker
#     r = call_item()
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py", line 275, in __call__
#     return self.fn(*self.args, **self.kwargs)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 625, in __call__
#     raise WorkerInterrupt() from e
# joblib.my_exceptions.WorkerInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py", line 431, in _process_worker
#     result_queue.put(_ResultItem(call_item.work_id, exception=exc))
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/externals/loky/backend/queues.py", line 191, in put
#     with self._wlock:
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/externals/loky/backend/synchronize.py", line 112, in __enter__
#     return self._semlock.acquire()
# KeyboardInterrupt
# Process LokyProcess-57:
# Traceback (most recent call last):
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 620, in __call__
#     return self.func(*args, **kwargs)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/parallel.py", line 288, in __call__
#     return [func(*args, **kwargs)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/parallel.py", line 288, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/sklearn/utils/parallel.py", line 123, in __call__
#     return self.function(*args, **kwargs)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/sklearn/svm/_base.py", line 252, in fit
#     fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/sklearn/svm/_base.py", line 331, in _dense_fit
#     ) = libsvm.fit(
# KeyboardInterrupt
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py", line 428, in _process_worker
#     r = call_item()
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py", line 275, in __call__
#     return self.fn(*self.args, **self.kwargs)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 625, in __call__
#     raise WorkerInterrupt() from e
# joblib.my_exceptions.WorkerInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py", line 431, in _process_worker
#     result_queue.put(_ResultItem(call_item.work_id, exception=exc))
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/externals/loky/backend/queues.py", line 191, in put
#     with self._wlock:
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/externals/loky/backend/synchronize.py", line 112, in __enter__
#     return self._semlock.acquire()
# KeyboardInterrupt
# Process LokyProcess-65:
# Traceback (most recent call last):
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 620, in __call__
#     return self.func(*args, **kwargs)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/parallel.py", line 288, in __call__
#     return [func(*args, **kwargs)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/parallel.py", line 288, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/sklearn/utils/parallel.py", line 123, in __call__
#     return self.function(*args, **kwargs)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/sklearn/svm/_base.py", line 252, in fit
#     fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/sklearn/svm/_base.py", line 331, in _dense_fit
#     ) = libsvm.fit(
# KeyboardInterrupt
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py", line 428, in _process_worker
#     r = call_item()
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py", line 275, in __call__
#     return self.fn(*self.args, **self.kwargs)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 625, in __call__
#     raise WorkerInterrupt() from e
# joblib.my_exceptions.WorkerInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py", line 431, in _process_worker
#     result_queue.put(_ResultItem(call_item.work_id, exception=exc))
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/externals/loky/backend/queues.py", line 191, in put
#     with self._wlock:
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/externals/loky/backend/synchronize.py", line 112, in __enter__
#     return self._semlock.acquire()
# KeyboardInterrupt
# Process LokyProcess-63:
# Traceback (most recent call last):
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 620, in __call__
#     return self.func(*args, **kwargs)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/parallel.py", line 288, in __call__
#     return [func(*args, **kwargs)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/parallel.py", line 288, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/sklearn/utils/parallel.py", line 123, in __call__
#     return self.function(*args, **kwargs)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/sklearn/svm/_base.py", line 252, in fit
#     fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/sklearn/svm/_base.py", line 331, in _dense_fit
#     ) = libsvm.fit(
# KeyboardInterrupt
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py", line 428, in _process_worker
#     r = call_item()
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py", line 275, in __call__
#     return self.fn(*self.args, **self.kwargs)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 625, in __call__
#     raise WorkerInterrupt() from e
# joblib.my_exceptions.WorkerInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py", line 431, in _process_worker
#     result_queue.put(_ResultItem(call_item.work_id, exception=exc))
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/externals/loky/backend/queues.py", line 191, in put
#     with self._wlock:
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/externals/loky/backend/synchronize.py", line 112, in __enter__
#     return self._semlock.acquire()
# KeyboardInterrupt
# Process LokyProcess-60:
# Traceback (most recent call last):
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 620, in __call__
#     return self.func(*args, **kwargs)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/parallel.py", line 288, in __call__
#     return [func(*args, **kwargs)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/parallel.py", line 288, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/sklearn/utils/parallel.py", line 123, in __call__
#     return self.function(*args, **kwargs)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/sklearn/svm/_base.py", line 252, in fit
#     fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/sklearn/svm/_base.py", line 331, in _dense_fit
#     ) = libsvm.fit(
# KeyboardInterrupt
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py", line 428, in _process_worker
#     r = call_item()
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py", line 275, in __call__
#     return self.fn(*self.args, **self.kwargs)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 625, in __call__
#     raise WorkerInterrupt() from e
# joblib.my_exceptions.WorkerInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py", line 431, in _process_worker
#     result_queue.put(_ResultItem(call_item.work_id, exception=exc))
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/externals/loky/backend/queues.py", line 191, in put
#     with self._wlock:
#   File "/home/tim/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/externals/loky/backend/synchronize.py", line 112, in __enter__
#     return self._semlock.acquire()
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/parallel.py:975, in Parallel.retrieve(self)
#     974 if getattr(self._backend, 'supports_timeout', False):
# --> 975     self._output.extend(job.get(timeout=self.timeout))
#     976 else:
#
# File ~/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/_parallel_backends.py:567, in LokyBackend.wrap_future_result(future, timeout)
#     566 try:
# --> 567     return future.result(timeout=timeout)
#     568 except CfTimeoutError as e:
#
# File /usr/lib/python3.8/concurrent/futures/_base.py:439, in Future.result(self, timeout)
#     437     return self.__get_result()
# --> 439 self._condition.wait(timeout)
#     441 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /usr/lib/python3.8/threading.py:302, in Condition.wait(self, timeout)
#     301 if timeout is None:
# --> 302     waiter.acquire()
#     303     gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 search_train_evaluate(x, y, "f1_macro")
#
# Cell In[19], line 9, in search_train_evaluate(x, y, parameter_search_scoring)
#       6 print()
#       8 ps = ParamSearch()
# ----> 9 clf = ps.param_search(x, y, parameter_search_scoring)
#      10 clf.best_params_
#      12 with open(params_path, "w") as outfile:
#      13     # writing to json file
#
# File ~/eyewitness-testimony-clf/src/learning/parameter_tuning.py:49, in ParamSearch.param_search(self, x, y, scoring)
#      41 svc = SVC()
#      42 clf = GridSearchCV(estimator=svc,
#      43                    param_grid=self.parameter_set,
#      44                    scoring=scoring,
#      45                    cv=skf.split(x, y),
#      46                    n_jobs=-1,
#      47                    )
# ---> 49 clf.fit(x, y)
#      51 print(clf.best_params_)
#      52 return clf
#
# File ~/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/sklearn/model_selection/_search.py:874, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     868     results = self._format_results(
#     869         all_candidate_params, n_splits, all_out, all_more_results
#     870     )
#     872     return results
# --> 874 self._run_search(evaluate_candidates)
#     876 # multimetric is determined here because in the case of a callable
#     877 # self.scoring the return type is only known after calling
#     878 first_test_score = all_out[0]["test_scores"]
#
# File ~/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/sklearn/model_selection/_search.py:1388, in GridSearchCV._run_search(self, evaluate_candidates)
#    1386 def _run_search(self, evaluate_candidates):
#    1387     """Search all candidates in param_grid"""
# -> 1388     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/sklearn/model_selection/_search.py:821, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     813 if self.verbose > 0:
#     814     print(
#     815         "Fitting {0} folds for each of {1} candidates,"
#     816         " totalling {2} fits".format(
#     817             n_splits, n_candidates, n_candidates * n_splits
#     818         )
#     819     )
# --> 821 out = parallel(
#     822     delayed(_fit_and_score)(
#     823         clone(base_estimator),
#     824         X,
#     825         y,
#     826         train=train,
#     827         test=test,
#     828         parameters=parameters,
#     829         split_progress=(split_idx, n_splits),
#     830         candidate_progress=(cand_idx, n_candidates),
#     831         **fit_and_score_kwargs,
#     832     )
#     833     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     834         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     835     )
#     836 )
#     838 if len(out) < 1:
#     839     raise ValueError(
#     840         "No fits were performed. "
#     841         "Was the CV iterator empty? "
#     842         "Were there no candidates?"
#     843     )
#
# File ~/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/sklearn/utils/parallel.py:63, in Parallel.__call__(self, iterable)
#      58 config = get_config()
#      59 iterable_with_config = (
#      60     (_with_config(delayed_func, config), args, kwargs)
#      61     for delayed_func, args, kwargs in iterable
#      62 )
# ---> 63 return super().__call__(iterable_with_config)
#
# File ~/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/parallel.py:1098, in Parallel.__call__(self, iterable)
#    1095     self._iterating = False
#    1097 with self._backend.retrieval_context():
# -> 1098     self.retrieve()
#    1099 # Make sure that we get a last message telling us we are done
#    1100 elapsed_time = time.time() - self._start_time
#
# File ~/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/parallel.py:997, in Parallel.retrieve(self)
#     991 if (backend is not None and
#     992         hasattr(backend, 'abort_everything')):
#     993     # If the backend is managed externally we need to make sure
#     994     # to leave it in a working state to allow for future jobs
#     995     # scheduling.
#     996     ensure_ready = self._managed_backend
# --> 997     backend.abort_everything(ensure_ready=ensure_ready)
#     998 raise
#
# File ~/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/_parallel_backends.py:586, in LokyBackend.abort_everything(self, ensure_ready)
#     583 def abort_everything(self, ensure_ready=True):
#     584     """Shutdown the workers and restart a new one with the same parameters
#     585     """
# --> 586     self._workers.terminate(kill_workers=True)
#     587     self._workers = None
#     589     if ensure_ready:
#
# File ~/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/executor.py:74, in MemmappingExecutor.terminate(self, kill_workers)
#      73 def terminate(self, kill_workers=False):
# ---> 74     self.shutdown(kill_workers=kill_workers)
#      75     if kill_workers:
#      76         # When workers are killed in such a brutal manner, they cannot
#      77         # execute the finalizer of their shared memmaps. The refcount of
#    (...)
#      83
#      84         # unregister temporary resources from all contexts
#      85         with self._submit_resize_lock:
#
# File ~/eyewitness-testimony-clf/venv/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py:1199, in ProcessPoolExecutor.shutdown(self, wait, kill_workers)
#    1196         self._executor_manager_thread_wakeup.wakeup()
#    1198 if executor_manager_thread is not None and wait:
# -> 1199     executor_manager_thread.join()
#    1201 # To reduce the risk of opening too many files, remove references to
#    1202 # objects that use file descriptors.
#    1203 self._executor_manager_thread = None
#
# File /usr/lib/python3.8/threading.py:1011, in Thread.join(self, timeout)
#    1008     raise RuntimeError("cannot join current thread")
#    1010 if timeout is None:
# -> 1011     self._wait_for_tstate_lock()
#    1012 else:
#    1013     # the behavior of a negative timeout isn't documented, but
#    1014     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1015     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File /usr/lib/python3.8/threading.py:1027, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1025 if lock is None:  # already determined that the C code is done
#    1026     assert self._is_stopped
# -> 1027 elif lock.acquire(block, timeout):
#    1028     lock.release()
#    1029     self._stop()
#
# KeyboardInterrupt:

# %% [markdown]
# # MISC

# %%
search_train_evaluate(x, y, "roc_auc")
search_train_evaluate(x, y, "accuracy")
search_train_evaluate(x, y, "f1_macro")
# Out:
# Evaluation with roc_auc scoring in parameter search
#
# {'C': 25, 'class_weight': 'balanced', 'gamma': 0.01, 'kernel': 'poly'}
# {'C': 25, 'class_weight': 'balanced', 'gamma': 0.01, 'kernel': 'poly'}
#
# printing roc_auc measures
# avg (train): 0.685739134484966
# std (train): 0.005890614466350203
# avg (validation): 0.6284060326637272
# std (validation): 0.026585157709627123
#
# printing accuracy measures
# avg (train): 0.6063973036392083
# std (train): 0.004416413923882217
# avg (validation): 0.5856818768747889
# std (validation): 0.017021042823399606
#
# printing f1_macro measures
# avg (train): 0.5724660670126106
# std (train): 0.00376146859675797
# avg (validation): 0.5501501478082254
# std (validation): 0.014963874763638769
#               precision    recall  f1-score   support
#
#            0       0.32      0.65      0.42       839
#            1       0.84      0.57      0.68      2709
#
#     accuracy                           0.59      3548
#    macro avg       0.58      0.61      0.55      3548
# weighted avg       0.71      0.59      0.62      3548
#
# Evaluation with accuracy scoring in parameter search
#
# {'C': 5, 'class_weight': 'balanced', 'gamma': 1, 'kernel': 'rbf'}
# {'C': 5, 'class_weight': 'balanced', 'gamma': 1, 'kernel': 'rbf'}
#
# printing roc_auc measures
# avg (train): 1.0
# std (train): 0.0
# avg (validation): 0.604892720680281
# std (validation): 0.014216448575109893
#
# printing accuracy measures
# avg (train): 1.0
# std (train): 0.0
# avg (validation): 0.7587369633882278
# std (validation): 0.0016869904662969038
#
# printing f1_macro measures
# avg (train): 1.0
# std (train): 0.0
# avg (validation): 0.4601678232632388
# std (validation): 0.011850310657832392
#               precision    recall  f1-score   support
#
#            0       0.38      0.03      0.06       839
#            1       0.77      0.98      0.86      2709
#
#     accuracy                           0.76      3548
#    macro avg       0.57      0.51      0.46      3548
# weighted avg       0.68      0.76      0.67      3548
#
# Evaluation with roc_auc scoring in parameter search
#
# {'C': 25, 'class_weight': 'balanced', 'gamma': 0.01, 'kernel': 'poly'}
# {'C': 25, 'class_weight': 'balanced', 'gamma': 0.01, 'kernel': 'poly'}
#
# printing roc_auc measures
# avg (train): 0.685739134484966
# std (train): 0.005890614466350203
# avg (validation): 0.6284060326637272
# std (validation): 0.026585157709627123
#
# printing accuracy measures
# avg (train): 0.6063973036392083
# std (train): 0.004416413923882217
# avg (validation): 0.5856818768747889
# std (validation): 0.017021042823399606
#
# printing f1_macro measures
# avg (train): 0.5724660670126106
# std (train): 0.00376146859675797
# avg (validation): 0.5501501478082254
# std (validation): 0.014963874763638769
#               precision    recall  f1-score   support
#
#            0       0.32      0.65      0.42       839
#            1       0.84      0.57      0.68      2709
#
#     accuracy                           0.59      3548
#    macro avg       0.58      0.61      0.55      3548
# weighted avg       0.71      0.59      0.62      3548

# %% [markdown]
# ## Parameter search with AUC scoring

# %%
params_path = os.path.join(output_data, "best_params_auc.json")

# %%
ps = ParamSearch()
clf = ps.param_search(x, y, "roc_auc")
clf.best_params_
# Out:
# {'C': 1, 'class_weight': 'balanced', 'gamma': 0.1, 'kernel': 'rbf'}
# {'C': 1, 'class_weight': 'balanced', 'gamma': 0.1, 'kernel': 'rbf'}

# %%
with open(params_path, "w") as outfile:
    # writing to json file
    json.dump(clf.best_params_, outfile)

# %%
with open(params_path, 'r') as openfile:
    # Reading from json file
    best_params = json.load(openfile)

# %%
best_params
# Out:
# {'C': 1, 'class_weight': 'balanced', 'gamma': 0.1, 'kernel': 'rbf'}

# %%
svc = SVC(**best_params, probability=True)
evaluate_scores(x=x,
                y=y,
                clf=svc,
                scoring_method="roc_auc")
# Out:
# printing roc_auc measures
# avg (train): 0.8078479246470351
# std (train): 0.004291630641423225
# avg (validation): 0.6294530945426859
# std (validation): 0.022508037216873583

# %%
svc = SVC(**best_params)
evaluate_scores(x=x,
                y=y,
                clf=svc,
                scoring_method="f1_macro")
# Out:
# printing accuracy measures
# avg (train): 0.7022966627372043
# std (train): 0.00721348586797871
# avg (validation): 0.6135807227000933
# std (validation): 0.01593171051163849

# %%
splits = get_splits(x, y)
y_pred = cross_val_predict(svc, x, y, cv=splits)

plot_hist(y_pred, "predictions")

report = metrics.classification_report(y_true=y, y_pred=y_pred)

print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.32      0.58      0.42       839
#            1       0.83      0.62      0.71      2709
#
#     accuracy                           0.61      3548
#    macro avg       0.58      0.60      0.56      3548
# weighted avg       0.71      0.61      0.64      3548

# %% [markdown]
# ## Parameter search with accuracy scoring

# %%
params_path = os.path.join(output_data, "best_params_accuracy.json")

# %%
ps = ParamSearch()
clf = ps.param_search(x, y, "accuracy")
clf.best_params_
# Out:
# {'C': 5, 'class_weight': 'balanced', 'gamma': 1, 'kernel': 'rbf'}
# {'C': 5, 'class_weight': 'balanced', 'gamma': 1, 'kernel': 'rbf'}

# %%
with open(params_path, "w") as outfile:
    # writing to json file
    json.dump(clf.best_params_, outfile)

# %%
with open(params_path, 'r') as openfile:
    # Reading from json file
    best_params = json.load(openfile)

# %%
svc = SVC(**best_params)
evaluate_scores(x=x,
                y=y,
                clf=svc,
                scoring_method="roc_auc")
# Out:
# printing roc_auc measures
# avg (train): 1.0
# std (train): 0.0
# avg (validation): 0.604892720680281
# std (validation): 0.014216448575109893

# %%
svc = SVC(**best_params)
evaluate_scores(x=x,
                y=y,
                clf=svc,
                scoring_method="accuracy")
# Out:
# printing accuracy measures
# avg (train): 1.0
# std (train): 0.0
# avg (validation): 0.7587369633882278
# std (validation): 0.0016869904662969038

# %%
splits = get_splits(x, y)
y_pred = cross_val_predict(svc, x, y, cv=splits)

plot_hist(y_pred, "predictions")

report = metrics.classification_report(y_true=y, y_pred=y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.38      0.03      0.06       839
#            1       0.77      0.98      0.86      2709
#
#     accuracy                           0.76      3548
#    macro avg       0.57      0.51      0.46      3548
# weighted avg       0.68      0.76      0.67      3548

# %% [markdown]
# ## Parameter search with F1 scoring

# %%
params_path = os.path.join(output_data, "best_params_f1.json")

# %%
ps = ParamSearch()
clf = ps.param_search(x, y, "f1_macro")
clf.best_params_
# Out:
# {'C': 1, 'class_weight': 'balanced', 'gamma': 0.1, 'kernel': 'rbf'}
# {'C': 1, 'class_weight': 'balanced', 'gamma': 0.1, 'kernel': 'rbf'}

# %%
with open(params_path, "w") as outfile:
    # writing to json file
    json.dump(clf.best_params_, outfile)
    
with open(params_path, 'r') as openfile:
    # Reading from json file
    best_params = json.load(openfile)

# %%
svc = SVC(**best_params)
evaluate_scores(x=x,
                y=y,
                clf=svc,
                scoring_method="roc_auc")

svc = SVC(**best_params)
evaluate_scores(x=x,
                y=y,
                clf=svc,
                scoring_method="accuracy")

svc = SVC(**best_params)
evaluate_scores(x=x,
                y=y,
                clf=svc,
                scoring_method="f1_macro")
# Out:
# printing roc_auc measures
# avg (train): 0.8078479246470351
# std (train): 0.004291630641423225
# avg (validation): 0.6294530945426859
# std (validation): 0.022508037216873583
# printing accuracy measures
# avg (train): 0.7022966627372043
# std (train): 0.00721348586797871
# avg (validation): 0.6135807227000933
# std (validation): 0.01593171051163849
# printing f1_macro measures
# avg (train): 0.6647386200350384
# std (train): 0.0052663803401243195
# avg (validation): 0.5634554587730671
# std (validation): 0.017325753120825755

# %%
splits = get_splits(x, y)
y_pred = cross_val_predict(svc, x, y, cv=splits)

plot_hist(y_pred, "predictions")

report = metrics.classification_report(y_true=y, y_pred=y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.32      0.58      0.42       839
#            1       0.83      0.62      0.71      2709
#
#     accuracy                           0.61      3548
#    macro avg       0.58      0.60      0.56      3548
# weighted avg       0.71      0.61      0.64      3548

# %%
splits = get_splits(x, y)

conf_mat_creator = ConfusionMatrixCreator(clf=svc)
conf_mat = conf_mat_creator.calculate_avg_conf_matrix(x, y, splits)

print(conf_mat)

plot_conf_mat(conf_mat)
# Out:
# [[0.58158683 0.41841317]
#  [0.37652973 0.62347027]]
